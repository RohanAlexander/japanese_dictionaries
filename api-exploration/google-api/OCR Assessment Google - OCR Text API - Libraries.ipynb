# %% [markdown]
# https://cloud.google.com/vision/docs/pdf

# %%
import os
from os import path
path = path.expanduser(r'E:\Users\Usuario\Downloads\r-api-267704-1c8678a6618a.json')
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = path

# %%
from os import path
image_path = path.expanduser(r'E:\Users\Usuario\Documents\OCR project\OCR_project\inputs\00-sample-pages_1-cropped.png')

# %%
image_url = 'https://github.com/RohanAlexander/japanese_dictionaries/blob/master/inputs/00-sample-pages_1-cropped.png?raw=true'

# %%
#image_url = "https://raw.githubusercontent.com/MicrosoftDocs/azure-docs/master/articles/cognitive-services/Computer-vision/Images/readsample.jpg"

from PIL import Image
import requests
from io import BytesIO

response = requests.get(image_url)
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1588x2776 at 0x27928ECDE10>

# %%
def detect_text(path):
    """Detects text in the file."""
    from google.cloud import vision
    import io
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.types.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations
    print('Texts:')

    for text in texts:
        print('\n"{}"'.format(text.description))

        vertices = (['({},{})'.format(vertex.x, vertex.y)
                    for vertex in text.bounding_poly.vertices])

        print('bounds: {}'.format(','.join(vertices)))

    if response.error.message:
        raise Exception(
            '{}\nFor more info on error messages, check: '
            'https://cloud.google.com/apis/design/errors'.format(
                response.error.message))

# %%
detect_text(image_path)
# Out:
# Texts:
#
# "1本の傘た二人でoすこと。多く男女二人の場合に一あS ん影「哀腕](名) 真れにやさしいこと
# あいをん結(哀猿](名) 悲しい撃で噂く猿。
# ATAA (Iron] (4)(神短にはなまって、「アイーロ 一あいえん あ 「合線】(名) むっびあふことのでき
# る繰。ーきえん【合縁奇線](名)0合ふも合
# こと。1しん[愛郷心](名) 愛郷の精神。
# '(愛敬](名) 0人づきの ょいこ
# と。あいそのょいこと。世辞のょいこと。①顔のか」
# はゆらしいこと。@俳優が花道で見物の方へ見たむ
# あいぐん-じょら5ゃくp一愛瑠陰約〕(名)
# 愛輝は猪洲国黒龍江省の都合。威曾八年(一八五八)
# 清·露の間に黒龍江を雨固の.固境とすることに就い
# て、の地で結ばれた旅約。
# S4° Aるる°
# ャ
# AJS4° O又は 微製品。O西洋びの°
# 髪の毛をちちらせる小形の鰻。®ルフ用の競の
# ゼ 楽 OK時盤な線。
# ·(藍翁](名)藍色た帯びてゐぁこと
# ーねずみ(藍気鼠](名) (あいれずみ)
# --あいぜん「愛敬愛染](名) 【俳]|あいけぁる
# お°-トャANリン Iron discipline] (¥)| AS-#S 認【相生】 (): に生い出る
# --ざし【相生播](名)男松と
# 女松とた揺し、根じめに戴柑子を 用ひたもの。
# の-まつ[相生松](名) 兵庫無加古郡高砂町高砂
# 神社の境内の雛松。高砂の松。|-ぼん(相生盆}
# (名)婚騰の折に用ひる男島と女島とを並べた盆景。
# --むすび「相生結](名) 尊通の女結びの一端か
# (あいぜんみょうおう)(愛染明王)。ーあばた[愛
# 敬這痕」(名)愛敬があるやうに見たるあばた。一あいけい【愛敬】(名)愛し敬ふこと
# -げ「愛敬毛](名) 女の雲や頭髪のおくれ毛。
# に愛敬を添へろからいふ。|しょうばい
# [愛敬商賓](名)待合。遊郭。愛敬がなくては立|あいげん[愛眼] (名) 【俳J俳の慈悲の眼。
# ちゆかぬからいふ。ーずきあい[愛敬附一あい-と [愛顧】(名)且かけてやること。引立て
# 合](名)なみなみのつきぁひ。警通の 交際。
# ずく 駅)}[愛敬附~](自動、ヵ四)愛あい-N [愛護](名)かはのがり保護すること。
# ...
