# %% [markdown]
# # Optical Character Recognition (OCR) - Kindai-OCR

# %% [markdown]
# ## 1 Validate environment

# %% [markdown]
# This notebook was created using Colab from Google. It is important to change the Runtime configuration to GPU before running it.

# %% [markdown]
# ### 1.1 Validate CUDA version

# %% [markdown]
# We need to validate if the environment provide a CUDA version.

# %%
# !nvidia-smi
# Out:
# Sun Nov 29 19:36:52 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.38       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### 1.1 Verify CUDA and Torch

# %% [markdown]
# The following code validates whether or not CUDA is available. It should be True to continue the process.

# %%
import torch
torch.cuda.is_available()
# Output would be True if Pytorch is using GPU otherwise it would be False.
# Out:
# True

# %% [markdown]
# This code validates the standard output. In this case it should be '/device:GPU:0'

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Standard output is '/device:GPU:0'
# Out:
# '/device:GPU:0'

# %% [markdown]
# #

# %% [markdown]
# ## Running test.py

# %% [markdown]
# Following the instructions given by the Kindai developers, in order for us to run text detection, we need to put the image(s) in the test folder. Moreover we have to use the code from the file test.py. To do that the following code is used to run .py files.

# %%
# %run test
# Out:
# ./pretrain/vgg16_bn-6c64b313.pth
# Loading text detection model from checkpoint ./pretrain/synweights_4600.pth
# total words/phones 5748
# ./data/test/00-sample_pages_3_sec_3.png
#
# infer/postproc time : 59.043/0.092
# save image
# ./data/test/00-sample_pages_3_sec_2.png
#
# infer/postproc time : 57.668/0.051
# save image
# ./data/test/00-sample_pages_3_sec_1.png
#
# infer/postproc time : 57.458/0.048
# save image
# ./data/test/00-sample_pages_3_sec_4.png
#
# infer/postproc time : 57.850/0.043
# save image
# elapsed time : 298.41661858558655s

# %% [markdown]
# This code extracts the infor from the xml file and creates a dataframe.

# %%
import pandas as pd 
import xml.etree.ElementTree as et 

xmlp = ET.XMLParser(encoding="utf-8")
#xtree = et.parse(xml_file, parser=xmlp)
xtree = et.parse("result.xml", parser=xmlp)
xroot = xtree.getroot() 

df = pd.DataFrame(columns=['tag','attributes','text','dpi','file','number','width','height','x','y'])
for elem in xroot.iter():
    #print(elem.tag, elem.attrib, elem.text)
    df = df.append({'tag': elem.tag, 'attributes':elem.attrib, 'text':elem.text}, ignore_index=True)
df.head()
# Out:
#                                               tag  ...    y
# 0  {http://codh.rois.ac.jp/modern-magazine/}paper  ...  NaN
# 1   {http://codh.rois.ac.jp/modern-magazine/}page  ...  NaN
# 2   {http://codh.rois.ac.jp/modern-magazine/}line  ...  NaN
# 3   {http://codh.rois.ac.jp/modern-magazine/}line  ...  NaN
# 4   {http://codh.rois.ac.jp/modern-magazine/}line  ...  NaN
#
# [5 rows x 10 columns]

# %% [markdown]
# After creating the dataframe, it is necessary to assign to each recognized line the corresponding paper. Moreover, the column name 'Attributes' contains nested dictionaries. The following code processes those dictionaries and assigns their values to new columns in the dataframe.

# %%
import ast
dpi = ""
file = ""
number = ""
width = ""
height = ""
x = ""
y = ""

for i in df.index:
    #print(df.iloc[i]['attributes'])

    if df.iloc[i]['attributes'].get('dpi') != None:
        dpi = df.iloc[i]['attributes'].get('dpi')
        df['dpi'].iloc[i] = dpi
    else:
        df['dpi'].iloc[i] = dpi
    if df.iloc[i]['attributes'].get('file') != None:
    file = df.iloc[i]['attributes'].get('file')
    df['file'].iloc[i] = file
    else:
        df['file'].iloc[i] = file
    if df.iloc[i]['attributes'].get('number') != None:
        number = df.iloc[i]['attributes'].get('number')
        df['number'].iloc[i] = number
    else:
        df['number'].iloc[i] = number
    if df.iloc[i]['attributes'].get('width') != None:
        width = df.iloc[i]['attributes'].get('width')
        df['width'].iloc[i] = width
    else:
        df['width'].iloc[i] = width
    if df.iloc[i]['attributes'].get('height') != None:
        height = df.iloc[i]['attributes'].get('height')
        df['height'].iloc[i] = height
    else:
        df['height'].iloc[i] = height
    if df.iloc[i]['attributes'].get('x') != None:
        x = df.iloc[i]['attributes'].get('x')
        df['x'].iloc[i] = x
    else:
        df['x'].iloc[i] = x
    if df.iloc[i]['attributes'].get('y') != None:
        y = df.iloc[i]['attributes'].get('y')
        df['y'].iloc[i] = y
    else:
        df['y'].iloc[i] = y

df
# Out:
#                                                 tag  ...    y
# 0    {http://codh.rois.ac.jp/modern-magazine/}paper  ...
# 1     {http://codh.rois.ac.jp/modern-magazine/}page  ...
# 2     {http://codh.rois.ac.jp/modern-magazine/}line  ...    0
# 3     {http://codh.rois.ac.jp/modern-magazine/}line  ...    0
# 4     {http://codh.rois.ac.jp/modern-magazine/}line  ...    0
# ..                                              ...  ...  ...
# 234   {http://codh.rois.ac.jp/modern-magazine/}line  ...  767
# 235   {http://codh.rois.ac.jp/modern-magazine/}line  ...  860
# 236   {http://codh.rois.ac.jp/modern-magazine/}line  ...  923
# 237   {http://codh.rois.ac.jp/modern-magazine/}line  ...  947
# 238   {http://codh.rois.ac.jp/modern-magazine/}line  ...  942
#
# [239 rows x 10 columns]

# %% [markdown]
# This code prints each character with the image name from which it was extracted.

# %%
for i in df.index:
  print('new line')
  if df.text.iloc[i] != None:
    for char in df.text.iloc[i]:
      if char != None:
        print(char, " | ", df.file.iloc[i])
# Out:
# new line
# new line
# new line
# あ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# 發  |  00-sample_pages_3_sec_3.png
# 路  |  00-sample_pages_3_sec_3.png
# 事  |  00-sample_pages_3_sec_3.png
# 、  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 形  |  00-sample_pages_3_sec_3.png
# 、  |  00-sample_pages_3_sec_3.png
# new line
# あ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# ち  |  00-sample_pages_3_sec_3.png
# 島  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 合  |  00-sample_pages_3_sec_3.png
# 巳  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# れ  |  00-sample_pages_3_sec_3.png
# せ  |  00-sample_pages_3_sec_3.png
# も  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# も  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# よ  |  00-sample_pages_3_sec_3.png
# new line
# あ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# す  |  00-sample_pages_3_sec_3.png
# り  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# 」  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# そ  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# 人  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# 爲  |  00-sample_pages_3_sec_3.png
# に  |  00-sample_pages_3_sec_3.png
# 信  |  00-sample_pages_3_sec_3.png
# 身  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# new line
# あ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# ん  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 及  |  00-sample_pages_3_sec_3.png
# 兵  |  00-sample_pages_3_sec_3.png
# 」  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# 起  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# 得  |  00-sample_pages_3_sec_3.png
# を  |  00-sample_pages_3_sec_3.png
# う  |  00-sample_pages_3_sec_3.png
# つ  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# 表  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# た  |  00-sample_pages_3_sec_3.png
# new line
# あ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# ん  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 心  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# 客  |  00-sample_pages_3_sec_3.png
# す  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# 東  |  00-sample_pages_3_sec_3.png
# な  |  00-sample_pages_3_sec_3.png
# ふ  |  00-sample_pages_3_sec_3.png
# す  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# 、  |  00-sample_pages_3_sec_3.png
# new line
# あ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# よ  |  00-sample_pages_3_sec_3.png
# う  |  00-sample_pages_3_sec_3.png
# 對  |  00-sample_pages_3_sec_3.png
# new line
# あ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# よ  |  00-sample_pages_3_sec_3.png
# う  |  00-sample_pages_3_sec_3.png
# new line
# あ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# よ  |  00-sample_pages_3_sec_3.png
# う  |  00-sample_pages_3_sec_3.png
# 對  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 婦  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# ら  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# さ  |  00-sample_pages_3_sec_3.png
# さ  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 彼  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# あ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# ま  |  00-sample_pages_3_sec_3.png
# う  |  00-sample_pages_3_sec_3.png
# new line
# （  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 教  |  00-sample_pages_3_sec_3.png
# 商  |  00-sample_pages_3_sec_3.png
# ）  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# 」  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# 毎  |  00-sample_pages_3_sec_3.png
# 金  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 造  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# も  |  00-sample_pages_3_sec_3.png
# が  |  00-sample_pages_3_sec_3.png
# な  |  00-sample_pages_3_sec_3.png
# て  |  00-sample_pages_3_sec_3.png
# て  |  00-sample_pages_3_sec_3.png
# は  |  00-sample_pages_3_sec_3.png
# 立  |  00-sample_pages_3_sec_3.png
# new line
# 府  |  00-sample_pages_3_sec_3.png
# が  |  00-sample_pages_3_sec_3.png
# は  |  00-sample_pages_3_sec_3.png
# ゆ  |  00-sample_pages_3_sec_3.png
# ら  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# く  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# ふ  |  00-sample_pages_3_sec_3.png
# 人  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# ○  |  00-sample_pages_3_sec_3.png
# つ  |  00-sample_pages_3_sec_3.png
# ば  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# な  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# 兌  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# ヒ  |  00-sample_pages_3_sec_3.png
# 直  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 九  |  00-sample_pages_3_sec_3.png
# 五  |  00-sample_pages_3_sec_3.png
# 五  |  00-sample_pages_3_sec_3.png
# 五  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# 又  |  00-sample_pages_3_sec_3.png
# 、  |  00-sample_pages_3_sec_3.png
# new line
# 隨  |  00-sample_pages_3_sec_3.png
# 後  |  00-sample_pages_3_sec_3.png
# 、  |  00-sample_pages_3_sec_3.png
# 三  |  00-sample_pages_3_sec_3.png
# 日  |  00-sample_pages_3_sec_3.png
# 目  |  00-sample_pages_3_sec_3.png
# に  |  00-sample_pages_3_sec_3.png
# 男  |  00-sample_pages_3_sec_3.png
# 始  |  00-sample_pages_3_sec_3.png
# に  |  00-sample_pages_3_sec_3.png
# 居  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# 併  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# み  |  00-sample_pages_3_sec_3.png
# か  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# も  |  00-sample_pages_3_sec_3.png
# ち  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 三  |  00-sample_pages_3_sec_3.png
# 日  |  00-sample_pages_3_sec_3.png
# 併  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# 新  |  00-sample_pages_3_sec_3.png
# 婦  |  00-sample_pages_3_sec_3.png
# が  |  00-sample_pages_3_sec_3.png
# 程  |  00-sample_pages_3_sec_3.png
# に  |  00-sample_pages_3_sec_3.png
# か  |  00-sample_pages_3_sec_3.png
# け  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# け  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# 居  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# ）  |  00-sample_pages_3_sec_3.png
# 手  |  00-sample_pages_3_sec_3.png
# 形  |  00-sample_pages_3_sec_3.png
# 活  |  00-sample_pages_3_sec_3.png
# 期  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# 後  |  00-sample_pages_3_sec_3.png
# 、  |  00-sample_pages_3_sec_3.png
# 支  |  00-sample_pages_3_sec_3.png
# 邦  |  00-sample_pages_3_sec_3.png
# を  |  00-sample_pages_3_sec_3.png
# 建  |  00-sample_pages_3_sec_3.png
# 則  |  00-sample_pages_3_sec_3.png
# す  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# 日  |  00-sample_pages_3_sec_3.png
# 數  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 思  |  00-sample_pages_3_sec_3.png
# 惡  |  00-sample_pages_3_sec_3.png
# 日  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# 佛  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# 容  |  00-sample_pages_3_sec_3.png
# 容  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# 𨥉  |  00-sample_pages_3_sec_3.png
# が  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# や  |  00-sample_pages_3_sec_3.png
# う  |  00-sample_pages_3_sec_3.png
# に  |  00-sample_pages_3_sec_3.png
# な  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# new line
# ち  |  00-sample_pages_3_sec_3.png
# ゆ  |  00-sample_pages_3_sec_3.png
# か  |  00-sample_pages_3_sec_3.png
# ぬ  |  00-sample_pages_3_sec_3.png
# か  |  00-sample_pages_3_sec_3.png
# ら  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# ふ  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# （  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# ら  |  00-sample_pages_3_sec_3.png
# ど  |  00-sample_pages_3_sec_3.png
# ん  |  00-sample_pages_3_sec_3.png
# み  |  00-sample_pages_3_sec_3.png
# ふ  |  00-sample_pages_3_sec_3.png
# う  |  00-sample_pages_3_sec_3.png
# お  |  00-sample_pages_3_sec_3.png
# う  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 集  |  00-sample_pages_3_sec_3.png
# 明  |  00-sample_pages_3_sec_3.png
# 王  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# す  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# こ  |  00-sample_pages_3_sec_3.png
# と  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# は  |  00-sample_pages_3_sec_3.png
# ゆ  |  00-sample_pages_3_sec_3.png
# ら  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# こ  |  00-sample_pages_3_sec_3.png
# こ  |  00-sample_pages_3_sec_3.png
# と  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 御  |  00-sample_pages_3_sec_3.png
# 併  |  00-sample_pages_3_sec_3.png
# 從  |  00-sample_pages_3_sec_3.png
# が  |  00-sample_pages_3_sec_3.png
# 花  |  00-sample_pages_3_sec_3.png
# 道  |  00-sample_pages_3_sec_3.png
# で  |  00-sample_pages_3_sec_3.png
# 見  |  00-sample_pages_3_sec_3.png
# 物  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# 方  |  00-sample_pages_3_sec_3.png
# へ  |  00-sample_pages_3_sec_3.png
# 見  |  00-sample_pages_3_sec_3.png
# そ  |  00-sample_pages_3_sec_3.png
# を  |  00-sample_pages_3_sec_3.png
# new line
# る  |  00-sample_pages_3_sec_3.png
# 樂  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 過  |  00-sample_pages_3_sec_3.png
# 業  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# る  |  00-sample_pages_3_sec_3.png
# は  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# ろ  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# る  |  00-sample_pages_3_sec_3.png
# 紙  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# ず  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# 和  |  00-sample_pages_3_sec_3.png
# む  |  00-sample_pages_3_sec_3.png
# 居  |  00-sample_pages_3_sec_3.png
# も  |  00-sample_pages_3_sec_3.png
# 二  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 教  |  00-sample_pages_3_sec_3.png
# 附  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 自  |  00-sample_pages_3_sec_3.png
# 動  |  00-sample_pages_3_sec_3.png
# 、  |  00-sample_pages_3_sec_3.png
# カ  |  00-sample_pages_3_sec_3.png
# 四  |  00-sample_pages_3_sec_3.png
# ）  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# new line
# 全  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# 五  |  00-sample_pages_3_sec_3.png
# 五  |  00-sample_pages_3_sec_3.png
# 五  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# つ  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 起  |  00-sample_pages_3_sec_3.png
# め  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# 交  |  00-sample_pages_3_sec_3.png
# 後  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# に  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 彼  |  00-sample_pages_3_sec_3.png
# を  |  00-sample_pages_3_sec_3.png
# 深  |  00-sample_pages_3_sec_3.png
# へ  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# か  |  00-sample_pages_3_sec_3.png
# ら  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# ふ  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# 歌  |  00-sample_pages_3_sec_3.png
# 最  |  00-sample_pages_3_sec_3.png
# 張  |  00-sample_pages_3_sec_3.png
# 」  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 校  |  00-sample_pages_3_sec_3.png
# か  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# や  |  00-sample_pages_3_sec_3.png
# う  |  00-sample_pages_3_sec_3.png
# に  |  00-sample_pages_3_sec_3.png
# 見  |  00-sample_pages_3_sec_3.png
# た  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# は  |  00-sample_pages_3_sec_3.png
# た  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# と  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# そ  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# よ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# こ  |  00-sample_pages_3_sec_3.png
# と  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 世  |  00-sample_pages_3_sec_3.png
# 然  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# よ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# ゝ  |  00-sample_pages_3_sec_3.png
# こ  |  00-sample_pages_3_sec_3.png
# と  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# ○  |  00-sample_pages_3_sec_3.png
# 領  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# か  |  00-sample_pages_3_sec_3.png
# new line
# ）  |  00-sample_pages_3_sec_3.png
# こ  |  00-sample_pages_3_sec_3.png
# と  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# し  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# ゝ  |  00-sample_pages_3_sec_3.png
# こ  |  00-sample_pages_3_sec_3.png
# と  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 又  |  00-sample_pages_3_sec_3.png
# 、  |  00-sample_pages_3_sec_3.png
# new line
# の  |  00-sample_pages_3_sec_3.png
# 口  |  00-sample_pages_3_sec_3.png
# 結  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# い  |  00-sample_pages_3_sec_3.png
# や  |  00-sample_pages_3_sec_3.png
# う  |  00-sample_pages_3_sec_3.png
# す  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# そ  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# 詩  |  00-sample_pages_3_sec_3.png
# 歌  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# け  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 敢  |  00-sample_pages_3_sec_3.png
# 主  |  00-sample_pages_3_sec_3.png
# 三  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# 去  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# 云  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 西  |  00-sample_pages_3_sec_3.png
# 安  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# お  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# れ  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 面  |  00-sample_pages_3_sec_3.png
# new line
# い  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 一  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 一  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# 」  |  00-sample_pages_3_sec_3.png
# 形  |  00-sample_pages_3_sec_3.png
# 「  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# 」  |  00-sample_pages_3_sec_3.png
# new line
# べ  |  00-sample_pages_3_sec_3.png
# に  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 教  |  00-sample_pages_3_sec_3.png
# 組  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# ）  |  00-sample_pages_3_sec_3.png
# 月  |  00-sample_pages_3_sec_3.png
# 所  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 始  |  00-sample_pages_3_sec_3.png
# 五  |  00-sample_pages_3_sec_3.png
# た  |  00-sample_pages_3_sec_3.png
# 太  |  00-sample_pages_3_sec_3.png
# に  |  00-sample_pages_3_sec_3.png
# つ  |  00-sample_pages_3_sec_3.png
# け  |  00-sample_pages_3_sec_3.png
# new line
# し  |  00-sample_pages_3_sec_3.png
# 依  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 校  |  00-sample_pages_3_sec_3.png
# 異  |  00-sample_pages_3_sec_3.png
# 子  |  00-sample_pages_3_sec_3.png
# 」  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# か  |  00-sample_pages_3_sec_3.png
# は  |  00-sample_pages_3_sec_3.png
# け  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# 見  |  00-sample_pages_3_sec_3.png
# ス  |  00-sample_pages_3_sec_3.png
# new line
# し  |  00-sample_pages_3_sec_3.png
# ん  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 第  |  00-sample_pages_3_sec_3.png
# 心  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# ）  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 迄  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# 精  |  00-sample_pages_3_sec_3.png
# 精  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# し  |  00-sample_pages_3_sec_3.png
# け  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# け  |  00-sample_pages_3_sec_3.png
# 」  |  00-sample_pages_3_sec_3.png
# 」  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# new line
# ー  |  00-sample_pages_3_sec_3.png
# ひ  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 𨥉  |  00-sample_pages_3_sec_3.png
# 日  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# ）  |  00-sample_pages_3_sec_3.png
# ハ  |  00-sample_pages_3_sec_3.png
# 程  |  00-sample_pages_3_sec_3.png
# 白  |  00-sample_pages_3_sec_3.png
# ど  |  00-sample_pages_3_sec_3.png
# な  |  00-sample_pages_3_sec_3.png
# ふ  |  00-sample_pages_3_sec_3.png
# new line
# し  |  00-sample_pages_3_sec_3.png
# ま  |  00-sample_pages_3_sec_3.png
# も  |  00-sample_pages_3_sec_3.png
# り  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 數  |  00-sample_pages_3_sec_3.png
# 守  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# 始  |  00-sample_pages_3_sec_3.png
# 然  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# 時  |  00-sample_pages_3_sec_3.png
# 、  |  00-sample_pages_3_sec_3.png
# new line
# や  |  00-sample_pages_3_sec_3.png
# う  |  00-sample_pages_3_sec_3.png
# new line
# や  |  00-sample_pages_3_sec_3.png
# う  |  00-sample_pages_3_sec_3.png
# new line
# さ  |  00-sample_pages_3_sec_3.png
# さ  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# ）  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# く  |  00-sample_pages_3_sec_3.png
# new line
# あ  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# せ  |  00-sample_pages_3_sec_3.png
# ん  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# 、  |  00-sample_pages_3_sec_3.png
# new line
# そ  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# 相  |  00-sample_pages_3_sec_3.png
# 度  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# き  |  00-sample_pages_3_sec_3.png
# new line
# 。  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 數  |  00-sample_pages_3_sec_3.png
# 」  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# さ  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# 否  |  00-sample_pages_3_sec_3.png
# 得  |  00-sample_pages_3_sec_3.png
# も  |  00-sample_pages_3_sec_3.png
# new line
# （  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 樂  |  00-sample_pages_3_sec_3.png
# 」  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# ）  |  00-sample_pages_3_sec_3.png
# 佛  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# し  |  00-sample_pages_3_sec_3.png
# 好  |  00-sample_pages_3_sec_3.png
# む  |  00-sample_pages_3_sec_3.png
# こ  |  00-sample_pages_3_sec_3.png
# と  |  00-sample_pages_3_sec_3.png
# new line
# こ  |  00-sample_pages_3_sec_3.png
# は  |  00-sample_pages_3_sec_3.png
# れ  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# 程  |  00-sample_pages_3_sec_3.png
# の  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# や  |  00-sample_pages_3_sec_3.png
# う  |  00-sample_pages_3_sec_3.png
# が  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# （  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 等  |  00-sample_pages_3_sec_3.png
# を  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# る  |  00-sample_pages_3_sec_3.png
# 入  |  00-sample_pages_3_sec_3.png
# つ  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# よ  |  00-sample_pages_3_sec_3.png
# ヒ  |  00-sample_pages_3_sec_3.png
# ミ  |  00-sample_pages_3_sec_3.png
# new line
# ー  |  00-sample_pages_3_sec_3.png
# も  |  00-sample_pages_3_sec_3.png
# ち  |  00-sample_pages_3_sec_3.png
# 錢  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 條  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# 常  |  00-sample_pages_3_sec_3.png
# new line
# し  |  00-sample_pages_3_sec_3.png
# そ  |  00-sample_pages_3_sec_3.png
# う  |  00-sample_pages_3_sec_3.png
# 計  |  00-sample_pages_3_sec_3.png
# new line
# す  |  00-sample_pages_3_sec_3.png
# き  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# 親  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 般  |  00-sample_pages_3_sec_3.png
# 附  |  00-sample_pages_3_sec_3.png
# new line
# し  |  00-sample_pages_3_sec_3.png
# よ  |  00-sample_pages_3_sec_3.png
# う  |  00-sample_pages_3_sec_3.png
# ほ  |  00-sample_pages_3_sec_3.png
# い  |  00-sample_pages_3_sec_3.png
# 口  |  00-sample_pages_3_sec_3.png
# new line
# （  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# 教  |  00-sample_pages_3_sec_3.png
# 相  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 名  |  00-sample_pages_3_sec_3.png
# ）  |  00-sample_pages_3_sec_3.png
# new line
# し  |  00-sample_pages_3_sec_3.png
# あ  |  00-sample_pages_3_sec_3.png
# ば  |  00-sample_pages_3_sec_3.png
# た  |  00-sample_pages_3_sec_3.png
# （  |  00-sample_pages_3_sec_3.png
# 愛  |  00-sample_pages_3_sec_3.png
# new line
# 「  |  00-sample_pages_3_sec_3.png
# 詩  |  00-sample_pages_3_sec_3.png
# 歌  |  00-sample_pages_3_sec_3.png
# 。  |  00-sample_pages_3_sec_3.png
# new line
# 二  |  00-sample_pages_3_sec_3.png
# ）  |  00-sample_pages_3_sec_3.png
# 大  |  00-sample_pages_3_sec_3.png
# new line
# ○  |  00-sample_pages_3_sec_3.png
# new line
# し  |  00-sample_pages_3_sec_3.png
# や  |  00-sample_pages_3_sec_3.png
# new line
# る  |  00-sample_pages_3_sec_3.png
# new line
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# き  |  00-sample_pages_3_sec_2.png
# ま  |  00-sample_pages_3_sec_2.png
# う  |  00-sample_pages_3_sec_2.png
# 引  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# き  |  00-sample_pages_3_sec_2.png
# よ  |  00-sample_pages_3_sec_2.png
# う  |  00-sample_pages_3_sec_2.png
# 計  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# き  |  00-sample_pages_3_sec_2.png
# め  |  00-sample_pages_3_sec_2.png
# う  |  00-sample_pages_3_sec_2.png
# 判  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 又  |  00-sample_pages_3_sec_2.png
# 立  |  00-sample_pages_3_sec_2.png
# 」  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# か  |  00-sample_pages_3_sec_2.png
# れ  |  00-sample_pages_3_sec_2.png
# し  |  00-sample_pages_3_sec_2.png
# み  |  00-sample_pages_3_sec_2.png
# 位  |  00-sample_pages_3_sec_2.png
# く  |  00-sample_pages_3_sec_2.png
# 、  |  00-sample_pages_3_sec_2.png
# こ  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# き  |  00-sample_pages_3_sec_2.png
# こ  |  00-sample_pages_3_sec_2.png
# 之  |  00-sample_pages_3_sec_2.png
# 品  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# き  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 愛  |  00-sample_pages_3_sec_2.png
# 愛  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# な  |  00-sample_pages_3_sec_2.png
# ら  |  00-sample_pages_3_sec_2.png
# ず  |  00-sample_pages_3_sec_2.png
# も  |  00-sample_pages_3_sec_2.png
# も  |  00-sample_pages_3_sec_2.png
# に  |  00-sample_pages_3_sec_2.png
# 造  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# か  |  00-sample_pages_3_sec_2.png
# ん  |  00-sample_pages_3_sec_2.png
# 始  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# か  |  00-sample_pages_3_sec_2.png
# ん  |  00-sample_pages_3_sec_2.png
# 居  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# か  |  00-sample_pages_3_sec_2.png
# も  |  00-sample_pages_3_sec_2.png
# 品  |  00-sample_pages_3_sec_2.png
# へ  |  00-sample_pages_3_sec_2.png
# 「  |  00-sample_pages_3_sec_2.png
# 閣  |  00-sample_pages_3_sec_2.png
# 」  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# 尚  |  00-sample_pages_3_sec_2.png
# 野  |  00-sample_pages_3_sec_2.png
# 生  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 出  |  00-sample_pages_3_sec_2.png
# 出  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# 奇  |  00-sample_pages_3_sec_2.png
# 官  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# か  |  00-sample_pages_3_sec_2.png
# た  |  00-sample_pages_3_sec_2.png
# 路  |  00-sample_pages_3_sec_2.png
# 、  |  00-sample_pages_3_sec_2.png
# 合  |  00-sample_pages_3_sec_2.png
# 友  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# 老  |  00-sample_pages_3_sec_2.png
# 居  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# せ  |  00-sample_pages_3_sec_2.png
# よ  |  00-sample_pages_3_sec_2.png
# よ  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 問  |  00-sample_pages_3_sec_2.png
# に  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# か  |  00-sample_pages_3_sec_2.png
# き  |  00-sample_pages_3_sec_2.png
# 等  |  00-sample_pages_3_sec_2.png
# 、  |  00-sample_pages_3_sec_2.png
# 合  |  00-sample_pages_3_sec_2.png
# 錢  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# も  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# か  |  00-sample_pages_3_sec_2.png
# き  |  00-sample_pages_3_sec_2.png
# 品  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 合  |  00-sample_pages_3_sec_2.png
# 候  |  00-sample_pages_3_sec_2.png
# 」  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# 」  |  00-sample_pages_3_sec_2.png
# 疑  |  00-sample_pages_3_sec_2.png
# 三  |  00-sample_pages_3_sec_2.png
# 尚  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 未  |  00-sample_pages_3_sec_2.png
# 又  |  00-sample_pages_3_sec_2.png
# は  |  00-sample_pages_3_sec_2.png
# 石  |  00-sample_pages_3_sec_2.png
# を  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# か  |  00-sample_pages_3_sec_2.png
# 「  |  00-sample_pages_3_sec_2.png
# 「  |  00-sample_pages_3_sec_2.png
# 改  |  00-sample_pages_3_sec_2.png
# 」  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# ）  |  00-sample_pages_3_sec_2.png
# 恐  |  00-sample_pages_3_sec_2.png
# し  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# 心  |  00-sample_pages_3_sec_2.png
# 持  |  00-sample_pages_3_sec_2.png
# な  |  00-sample_pages_3_sec_2.png
# あ  |  00-sample_pages_3_sec_2.png
# ら  |  00-sample_pages_3_sec_2.png
# ば  |  00-sample_pages_3_sec_2.png
# し  |  00-sample_pages_3_sec_2.png
# た  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# あ  |  00-sample_pages_3_sec_2.png
# れ  |  00-sample_pages_3_sec_2.png
# く  |  00-sample_pages_3_sec_2.png
# き  |  00-sample_pages_3_sec_2.png
# 易  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 合  |  00-sample_pages_3_sec_2.png
# 折  |  00-sample_pages_3_sec_2.png
# 何  |  00-sample_pages_3_sec_2.png
# 」  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# ）  |  00-sample_pages_3_sec_2.png
# 直  |  00-sample_pages_3_sec_2.png
# 角  |  00-sample_pages_3_sec_2.png
# に  |  00-sample_pages_3_sec_2.png
# 出  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# ア  |  00-sample_pages_3_sec_2.png
# イ  |  00-sample_pages_3_sec_2.png
# ー  |  00-sample_pages_3_sec_2.png
# 才  |  00-sample_pages_3_sec_2.png
# ー  |  00-sample_pages_3_sec_2.png
# ー  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# お  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# 品  |  00-sample_pages_3_sec_2.png
# 相  |  00-sample_pages_3_sec_2.png
# 生  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# つ  |  00-sample_pages_3_sec_2.png
# し  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# 上  |  00-sample_pages_3_sec_2.png
# 生  |  00-sample_pages_3_sec_2.png
# 生  |  00-sample_pages_3_sec_2.png
# 出  |  00-sample_pages_3_sec_2.png
# る  |  00-sample_pages_3_sec_2.png
# 、  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# そ  |  00-sample_pages_3_sec_2.png
# ん  |  00-sample_pages_3_sec_2.png
# 品  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 終  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# ち  |  00-sample_pages_3_sec_2.png
# む  |  00-sample_pages_3_sec_2.png
# ひ  |  00-sample_pages_3_sec_2.png
# ひ  |  00-sample_pages_3_sec_2.png
# あ  |  00-sample_pages_3_sec_2.png
# ふ  |  00-sample_pages_3_sec_2.png
# こ  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# で  |  00-sample_pages_3_sec_2.png
# き  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# し  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# る  |  00-sample_pages_3_sec_2.png
# 左  |  00-sample_pages_3_sec_2.png
# ん  |  00-sample_pages_3_sec_2.png
# 結  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 愛  |  00-sample_pages_3_sec_2.png
# 疑  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# 五  |  00-sample_pages_3_sec_2.png
# 五  |  00-sample_pages_3_sec_2.png
# れ  |  00-sample_pages_3_sec_2.png
# に  |  00-sample_pages_3_sec_2.png
# や  |  00-sample_pages_3_sec_2.png
# さ  |  00-sample_pages_3_sec_2.png
# し  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# こ  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# 情  |  00-sample_pages_3_sec_2.png
# を  |  00-sample_pages_3_sec_2.png
# 述  |  00-sample_pages_3_sec_2.png
# べ  |  00-sample_pages_3_sec_2.png
# て  |  00-sample_pages_3_sec_2.png
# 熱  |  00-sample_pages_3_sec_2.png
# 心  |  00-sample_pages_3_sec_2.png
# に  |  00-sample_pages_3_sec_2.png
# 強  |  00-sample_pages_3_sec_2.png
# ふ  |  00-sample_pages_3_sec_2.png
# こ  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# こ  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# 又  |  00-sample_pages_3_sec_2.png
# 、  |  00-sample_pages_3_sec_2.png
# new line
# 接  |  00-sample_pages_3_sec_2.png
# 合  |  00-sample_pages_3_sec_2.png
# す  |  00-sample_pages_3_sec_2.png
# る  |  00-sample_pages_3_sec_2.png
# に  |  00-sample_pages_3_sec_2.png
# 、  |  00-sample_pages_3_sec_2.png
# new line
# あ  |  00-sample_pages_3_sec_2.png
# ら  |  00-sample_pages_3_sec_2.png
# ば  |  00-sample_pages_3_sec_2.png
# す  |  00-sample_pages_3_sec_2.png
# 商  |  00-sample_pages_3_sec_2.png
# 業  |  00-sample_pages_3_sec_2.png
# 用  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 常  |  00-sample_pages_3_sec_2.png
# 誌  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# き  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 將  |  00-sample_pages_3_sec_2.png
# 過  |  00-sample_pages_3_sec_2.png
# あ  |  00-sample_pages_3_sec_2.png
# な  |  00-sample_pages_3_sec_2.png
# た  |  00-sample_pages_3_sec_2.png
# か  |  00-sample_pages_3_sec_2.png
# ら  |  00-sample_pages_3_sec_2.png
# 情  |  00-sample_pages_3_sec_2.png
# 用  |  00-sample_pages_3_sec_2.png
# し  |  00-sample_pages_3_sec_2.png
# ま  |  00-sample_pages_3_sec_2.png
# し  |  00-sample_pages_3_sec_2.png
# た  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 意  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# 情  |  00-sample_pages_3_sec_2.png
# 用  |  00-sample_pages_3_sec_2.png
# を  |  00-sample_pages_3_sec_2.png
# new line
# 更  |  00-sample_pages_3_sec_2.png
# に  |  00-sample_pages_3_sec_2.png
# そ  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 結  |  00-sample_pages_3_sec_2.png
# 目  |  00-sample_pages_3_sec_2.png
# に  |  00-sample_pages_3_sec_2.png
# 通  |  00-sample_pages_3_sec_2.png
# し  |  00-sample_pages_3_sec_2.png
# た  |  00-sample_pages_3_sec_2.png
# 紙  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 然  |  00-sample_pages_3_sec_2.png
# び  |  00-sample_pages_3_sec_2.png
# 方  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# （  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# ）  |  00-sample_pages_3_sec_2.png
# ）  |  00-sample_pages_3_sec_2.png
# 縣  |  00-sample_pages_3_sec_2.png
# 應  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 折  |  00-sample_pages_3_sec_2.png
# に  |  00-sample_pages_3_sec_2.png
# 用  |  00-sample_pages_3_sec_2.png
# ひ  |  00-sample_pages_3_sec_2.png
# る  |  00-sample_pages_3_sec_2.png
# 男  |  00-sample_pages_3_sec_2.png
# 島  |  00-sample_pages_3_sec_2.png
# こ  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# 女  |  00-sample_pages_3_sec_2.png
# 島  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# を  |  00-sample_pages_3_sec_2.png
# 故  |  00-sample_pages_3_sec_2.png
# べ  |  00-sample_pages_3_sec_2.png
# た  |  00-sample_pages_3_sec_2.png
# 交  |  00-sample_pages_3_sec_2.png
# 終  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# の  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# ○  |  00-sample_pages_3_sec_2.png
# 子  |  00-sample_pages_3_sec_2.png
# 持  |  00-sample_pages_3_sec_2.png
# 結  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 望  |  00-sample_pages_3_sec_2.png
# 演  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# う  |  00-sample_pages_3_sec_2.png
# も  |  00-sample_pages_3_sec_2.png
# ん  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 相  |  00-sample_pages_3_sec_2.png
# 用  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# 英  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# ）  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# あ  |  00-sample_pages_3_sec_2.png
# ひ  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# こ  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# 入  |  00-sample_pages_3_sec_2.png
# れ  |  00-sample_pages_3_sec_2.png
# る  |  00-sample_pages_3_sec_2.png
# 三  |  00-sample_pages_3_sec_2.png
# 味  |  00-sample_pages_3_sec_2.png
# 經  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# ○  |  00-sample_pages_3_sec_2.png
# 諸  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 大  |  00-sample_pages_3_sec_2.png
# 彼  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 小  |  00-sample_pages_3_sec_2.png
# 要  |  00-sample_pages_3_sec_2.png
# 太  |  00-sample_pages_3_sec_2.png
# 要  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# 治  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 雖  |  00-sample_pages_3_sec_2.png
# 子  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# し  |  00-sample_pages_3_sec_2.png
# む  |  00-sample_pages_3_sec_2.png
# す  |  00-sample_pages_3_sec_2.png
# ひ  |  00-sample_pages_3_sec_2.png
# 、  |  00-sample_pages_3_sec_2.png
# 相  |  00-sample_pages_3_sec_2.png
# 生  |  00-sample_pages_3_sec_2.png
# 結  |  00-sample_pages_3_sec_2.png
# 三  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# 指  |  00-sample_pages_3_sec_2.png
# 如  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 女  |  00-sample_pages_3_sec_2.png
# 給  |  00-sample_pages_3_sec_2.png
# ひ  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 一  |  00-sample_pages_3_sec_2.png
# 今  |  00-sample_pages_3_sec_2.png
# を  |  00-sample_pages_3_sec_2.png
# new line
# 神  |  00-sample_pages_3_sec_2.png
# 社  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 近  |  00-sample_pages_3_sec_2.png
# 内  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 無  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# 高  |  00-sample_pages_3_sec_2.png
# 物  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 然  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# の  |  00-sample_pages_3_sec_2.png
# ま  |  00-sample_pages_3_sec_2.png
# つ  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 相  |  00-sample_pages_3_sec_2.png
# 生  |  00-sample_pages_3_sec_2.png
# 卷  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# 兵  |  00-sample_pages_3_sec_2.png
# 民  |  00-sample_pages_3_sec_2.png
# 無  |  00-sample_pages_3_sec_2.png
# 如  |  00-sample_pages_3_sec_2.png
# 古  |  00-sample_pages_3_sec_2.png
# 邦  |  00-sample_pages_3_sec_2.png
# 治  |  00-sample_pages_3_sec_2.png
# 的  |  00-sample_pages_3_sec_2.png
# 可  |  00-sample_pages_3_sec_2.png
# 高  |  00-sample_pages_3_sec_2.png
# 物  |  00-sample_pages_3_sec_2.png
# new line
# 女  |  00-sample_pages_3_sec_2.png
# 然  |  00-sample_pages_3_sec_2.png
# こ  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# を  |  00-sample_pages_3_sec_2.png
# 撰  |  00-sample_pages_3_sec_2.png
# し  |  00-sample_pages_3_sec_2.png
# 、  |  00-sample_pages_3_sec_2.png
# new line
# は  |  00-sample_pages_3_sec_2.png
# ぬ  |  00-sample_pages_3_sec_2.png
# も  |  00-sample_pages_3_sec_2.png
# 熱  |  00-sample_pages_3_sec_2.png
# に  |  00-sample_pages_3_sec_2.png
# よ  |  00-sample_pages_3_sec_2.png
# る  |  00-sample_pages_3_sec_2.png
# こ  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# 不  |  00-sample_pages_3_sec_2.png
# 思  |  00-sample_pages_3_sec_2.png
# 議  |  00-sample_pages_3_sec_2.png
# な  |  00-sample_pages_3_sec_2.png
# な  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# こ  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# new line
# る  |  00-sample_pages_3_sec_2.png
# 終  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# 一  |  00-sample_pages_3_sec_2.png
# で  |  00-sample_pages_3_sec_2.png
# new line
# 、  |  00-sample_pages_3_sec_2.png
# new line
# お  |  00-sample_pages_3_sec_2.png
# な  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# し  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# 易  |  00-sample_pages_3_sec_2.png
# 女  |  00-sample_pages_3_sec_2.png
# 親  |  00-sample_pages_3_sec_2.png
# 子  |  00-sample_pages_3_sec_2.png
# 凡  |  00-sample_pages_3_sec_2.png
# 第  |  00-sample_pages_3_sec_2.png
# 夫  |  00-sample_pages_3_sec_2.png
# 婦  |  00-sample_pages_3_sec_2.png
# 知  |  00-sample_pages_3_sec_2.png
# 己  |  00-sample_pages_3_sec_2.png
# 等  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 相  |  00-sample_pages_3_sec_2.png
# 思  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 歌  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# き  |  00-sample_pages_3_sec_2.png
# 左  |  00-sample_pages_3_sec_2.png
# ん  |  00-sample_pages_3_sec_2.png
# 公  |  00-sample_pages_3_sec_2.png
# 終  |  00-sample_pages_3_sec_2.png
# 奇  |  00-sample_pages_3_sec_2.png
# 經  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 合  |  00-sample_pages_3_sec_2.png
# よ  |  00-sample_pages_3_sec_2.png
# よ  |  00-sample_pages_3_sec_2.png
# 合  |  00-sample_pages_3_sec_2.png
# new line
# そ  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 物  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# そ  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 點  |  00-sample_pages_3_sec_2.png
# を  |  00-sample_pages_3_sec_2.png
# 五  |  00-sample_pages_3_sec_2.png
# に  |  00-sample_pages_3_sec_2.png
# 半  |  00-sample_pages_3_sec_2.png
# 分  |  00-sample_pages_3_sec_2.png
# つ  |  00-sample_pages_3_sec_2.png
# つ  |  00-sample_pages_3_sec_2.png
# 状  |  00-sample_pages_3_sec_2.png
# い  |  00-sample_pages_3_sec_2.png
# て  |  00-sample_pages_3_sec_2.png
# 合  |  00-sample_pages_3_sec_2.png
# は  |  00-sample_pages_3_sec_2.png
# せ  |  00-sample_pages_3_sec_2.png
# る  |  00-sample_pages_3_sec_2.png
# new line
# じ  |  00-sample_pages_3_sec_2.png
# new line
# や  |  00-sample_pages_3_sec_2.png
# new line
# ユ  |  00-sample_pages_3_sec_2.png
# ー  |  00-sample_pages_3_sec_2.png
# new line
# せ  |  00-sample_pages_3_sec_2.png
# 知  |  00-sample_pages_3_sec_2.png
# 變  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# を  |  00-sample_pages_3_sec_2.png
# 然  |  00-sample_pages_3_sec_2.png
# も  |  00-sample_pages_3_sec_2.png
# 外  |  00-sample_pages_3_sec_2.png
# 々  |  00-sample_pages_3_sec_2.png
# だ  |  00-sample_pages_3_sec_2.png
# し  |  00-sample_pages_3_sec_2.png
# し  |  00-sample_pages_3_sec_2.png
# new line
# （  |  00-sample_pages_3_sec_2.png
# 「  |  00-sample_pages_3_sec_2.png
# 百  |  00-sample_pages_3_sec_2.png
# ）  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# 」  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# け  |  00-sample_pages_3_sec_2.png
# き  |  00-sample_pages_3_sec_2.png
# き  |  00-sample_pages_3_sec_2.png
# か  |  00-sample_pages_3_sec_2.png
# ふ  |  00-sample_pages_3_sec_2.png
# ふ  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# こ  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# 事  |  00-sample_pages_3_sec_2.png
# new line
# 錢  |  00-sample_pages_3_sec_2.png
# 近  |  00-sample_pages_3_sec_2.png
# 」  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# 大  |  00-sample_pages_3_sec_2.png
# め  |  00-sample_pages_3_sec_2.png
# じ  |  00-sample_pages_3_sec_2.png
# て  |  00-sample_pages_3_sec_2.png
# て  |  00-sample_pages_3_sec_2.png
# て  |  00-sample_pages_3_sec_2.png
# あ  |  00-sample_pages_3_sec_2.png
# る  |  00-sample_pages_3_sec_2.png
# か  |  00-sample_pages_3_sec_2.png
# new line
# 報  |  00-sample_pages_3_sec_2.png
# じ  |  00-sample_pages_3_sec_2.png
# め  |  00-sample_pages_3_sec_2.png
# に  |  00-sample_pages_3_sec_2.png
# 張  |  00-sample_pages_3_sec_2.png
# 相  |  00-sample_pages_3_sec_2.png
# 子  |  00-sample_pages_3_sec_2.png
# を  |  00-sample_pages_3_sec_2.png
# 用  |  00-sample_pages_3_sec_2.png
# ひ  |  00-sample_pages_3_sec_2.png
# た  |  00-sample_pages_3_sec_2.png
# も  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 。  |  00-sample_pages_3_sec_2.png
# new line
# （  |  00-sample_pages_3_sec_2.png
# 愛  |  00-sample_pages_3_sec_2.png
# 知  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 生  |  00-sample_pages_3_sec_2.png
# ま  |  00-sample_pages_3_sec_2.png
# れ  |  00-sample_pages_3_sec_2.png
# 故  |  00-sample_pages_3_sec_2.png
# 務  |  00-sample_pages_3_sec_2.png
# を  |  00-sample_pages_3_sec_2.png
# 受  |  00-sample_pages_3_sec_2.png
# す  |  00-sample_pages_3_sec_2.png
# る  |  00-sample_pages_3_sec_2.png
# new line
# し  |  00-sample_pages_3_sec_2.png
# ざ  |  00-sample_pages_3_sec_2.png
# し  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 相  |  00-sample_pages_3_sec_2.png
# 生  |  00-sample_pages_3_sec_2.png
# 指  |  00-sample_pages_3_sec_2.png
# 」  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# ）  |  00-sample_pages_3_sec_2.png
# 易  |  00-sample_pages_3_sec_2.png
# 然  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# と  |  00-sample_pages_3_sec_2.png
# new line
# 相  |  00-sample_pages_3_sec_2.png
# 聞  |  00-sample_pages_3_sec_2.png
# 」  |  00-sample_pages_3_sec_2.png
# 名  |  00-sample_pages_3_sec_2.png
# 成  |  00-sample_pages_3_sec_2.png
# 東  |  00-sample_pages_3_sec_2.png
# 邦  |  00-sample_pages_3_sec_2.png
# 中  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# 世  |  00-sample_pages_3_sec_2.png
# あ  |  00-sample_pages_3_sec_2.png
# の  |  00-sample_pages_3_sec_2.png
# new line
# （  |  00-sample_pages_3_sec_2.png
# （  |  00-sample_pages_3_sec_2.png
# 「  |  00-sample_pages_3_sec_2.png
# new line
# 一  |  00-sample_pages_3_sec_2.png
# ...
# 合  |  00-sample_pages_3_sec_4.png
# 全  |  00-sample_pages_3_sec_4.png
# 」  |  00-sample_pages_3_sec_4.png
# 名  |  00-sample_pages_3_sec_4.png
# も  |  00-sample_pages_3_sec_4.png
# も  |  00-sample_pages_3_sec_4.png
# の  |  00-sample_pages_3_sec_4.png
# 遊  |  00-sample_pages_3_sec_4.png
# 長  |  00-sample_pages_3_sec_4.png
# で  |  00-sample_pages_3_sec_4.png
# 二  |  00-sample_pages_3_sec_4.png
# 人  |  00-sample_pages_3_sec_4.png
# が  |  00-sample_pages_3_sec_4.png
# 同  |  00-sample_pages_3_sec_4.png
# new line
# あ  |  00-sample_pages_3_sec_4.png
# い  |  00-sample_pages_3_sec_4.png
# け  |  00-sample_pages_3_sec_4.png
# い  |  00-sample_pages_3_sec_4.png
# （  |  00-sample_pages_3_sec_4.png
# 愛  |  00-sample_pages_3_sec_4.png
# 𨥉  |  00-sample_pages_3_sec_4.png
# 」  |  00-sample_pages_3_sec_4.png
# 名  |  00-sample_pages_3_sec_4.png
# 愛  |  00-sample_pages_3_sec_4.png
# し  |  00-sample_pages_3_sec_4.png
# 彼  |  00-sample_pages_3_sec_4.png
# ふ  |  00-sample_pages_3_sec_4.png
# こ  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# あ  |  00-sample_pages_3_sec_4.png
# い  |  00-sample_pages_3_sec_4.png
# け  |  00-sample_pages_3_sec_4.png
# あ  |  00-sample_pages_3_sec_4.png
# る  |  00-sample_pages_3_sec_4.png
# new line
# あ  |  00-sample_pages_3_sec_4.png
# い  |  00-sample_pages_3_sec_4.png
# ざ  |  00-sample_pages_3_sec_4.png
# ん  |  00-sample_pages_3_sec_4.png
# じ  |  00-sample_pages_3_sec_4.png
# よ  |  00-sample_pages_3_sec_4.png
# う  |  00-sample_pages_3_sec_4.png
# や  |  00-sample_pages_3_sec_4.png
# く  |  00-sample_pages_3_sec_4.png
# 引  |  00-sample_pages_3_sec_4.png
# new line
# 撰  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# れ  |  00-sample_pages_3_sec_4.png
# て  |  00-sample_pages_3_sec_4.png
# 、  |  00-sample_pages_3_sec_4.png
# 六  |  00-sample_pages_3_sec_4.png
# 年  |  00-sample_pages_3_sec_4.png
# 間  |  00-sample_pages_3_sec_4.png
# の  |  00-sample_pages_3_sec_4.png
# 掲  |  00-sample_pages_3_sec_4.png
# 造  |  00-sample_pages_3_sec_4.png
# 郎  |  00-sample_pages_3_sec_4.png
# 使  |  00-sample_pages_3_sec_4.png
# 府  |  00-sample_pages_3_sec_4.png
# 金  |  00-sample_pages_3_sec_4.png
# を  |  00-sample_pages_3_sec_4.png
# す  |  00-sample_pages_3_sec_4.png
# る  |  00-sample_pages_3_sec_4.png
# ゝ  |  00-sample_pages_3_sec_4.png
# こ  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# 信  |  00-sample_pages_3_sec_4.png
# を  |  00-sample_pages_3_sec_4.png
# 早  |  00-sample_pages_3_sec_4.png
# く  |  00-sample_pages_3_sec_4.png
# 致  |  00-sample_pages_3_sec_4.png
# 違  |  00-sample_pages_3_sec_4.png
# す  |  00-sample_pages_3_sec_4.png
# る  |  00-sample_pages_3_sec_4.png
# 目  |  00-sample_pages_3_sec_4.png
# 的  |  00-sample_pages_3_sec_4.png
# で  |  00-sample_pages_3_sec_4.png
# 、  |  00-sample_pages_3_sec_4.png
# new line
# 精  |  00-sample_pages_3_sec_4.png
# 神  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# 組  |  00-sample_pages_3_sec_4.png
# 國  |  00-sample_pages_3_sec_4.png
# 愛  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# 活  |  00-sample_pages_3_sec_4.png
# 定  |  00-sample_pages_3_sec_4.png
# の  |  00-sample_pages_3_sec_4.png
# 問  |  00-sample_pages_3_sec_4.png
# に  |  00-sample_pages_3_sec_4.png
# 造  |  00-sample_pages_3_sec_4.png
# 消  |  00-sample_pages_3_sec_4.png
# 在  |  00-sample_pages_3_sec_4.png
# を  |  00-sample_pages_3_sec_4.png
# 附  |  00-sample_pages_3_sec_4.png
# 因  |  00-sample_pages_3_sec_4.png
# の  |  00-sample_pages_3_sec_4.png
# 回  |  00-sample_pages_3_sec_4.png
# 近  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# す  |  00-sample_pages_3_sec_4.png
# る  |  00-sample_pages_3_sec_4.png
# こ  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# に  |  00-sample_pages_3_sec_4.png
# 就  |  00-sample_pages_3_sec_4.png
# い  |  00-sample_pages_3_sec_4.png
# new line
# 信  |  00-sample_pages_3_sec_4.png
# 的  |  00-sample_pages_3_sec_4.png
# 思  |  00-sample_pages_3_sec_4.png
# 想  |  00-sample_pages_3_sec_4.png
# を  |  00-sample_pages_3_sec_4.png
# 行  |  00-sample_pages_3_sec_4.png
# 發  |  00-sample_pages_3_sec_4.png
# す  |  00-sample_pages_3_sec_4.png
# る  |  00-sample_pages_3_sec_4.png
# こ  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# を  |  00-sample_pages_3_sec_4.png
# 無  |  00-sample_pages_3_sec_4.png
# 視  |  00-sample_pages_3_sec_4.png
# し  |  00-sample_pages_3_sec_4.png
# て  |  00-sample_pages_3_sec_4.png
# 、  |  00-sample_pages_3_sec_4.png
# new line
# 宗  |  00-sample_pages_3_sec_4.png
# 教  |  00-sample_pages_3_sec_4.png
# 道  |  00-sample_pages_3_sec_4.png
# 色  |  00-sample_pages_3_sec_4.png
# 上  |  00-sample_pages_3_sec_4.png
# 、  |  00-sample_pages_3_sec_4.png
# 結  |  00-sample_pages_3_sec_4.png
# 點  |  00-sample_pages_3_sec_4.png
# 點  |  00-sample_pages_3_sec_4.png
# 成  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# 目  |  00-sample_pages_3_sec_4.png
# さ  |  00-sample_pages_3_sec_4.png
# れ  |  00-sample_pages_3_sec_4.png
# て  |  00-sample_pages_3_sec_4.png
# あ  |  00-sample_pages_3_sec_4.png
# た  |  00-sample_pages_3_sec_4.png
# 神  |  00-sample_pages_3_sec_4.png
# や  |  00-sample_pages_3_sec_4.png
# 道  |  00-sample_pages_3_sec_4.png
# も  |  00-sample_pages_3_sec_4.png
# 信  |  00-sample_pages_3_sec_4.png
# 條  |  00-sample_pages_3_sec_4.png
# new line
# あ  |  00-sample_pages_3_sec_4.png
# る  |  00-sample_pages_3_sec_4.png
# 合  |  00-sample_pages_3_sec_4.png
# 個  |  00-sample_pages_3_sec_4.png
# の  |  00-sample_pages_3_sec_4.png
# の  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# か  |  00-sample_pages_3_sec_4.png
# れ  |  00-sample_pages_3_sec_4.png
# て  |  00-sample_pages_3_sec_4.png
# し  |  00-sample_pages_3_sec_4.png
# め  |  00-sample_pages_3_sec_4.png
# し  |  00-sample_pages_3_sec_4.png
# 合  |  00-sample_pages_3_sec_4.png
# せ  |  00-sample_pages_3_sec_4.png
# て  |  00-sample_pages_3_sec_4.png
# あ  |  00-sample_pages_3_sec_4.png
# る  |  00-sample_pages_3_sec_4.png
# 所  |  00-sample_pages_3_sec_4.png
# 誌  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# 兵  |  00-sample_pages_3_sec_4.png
# の  |  00-sample_pages_3_sec_4.png
# 致  |  00-sample_pages_3_sec_4.png
# 認  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# 一  |  00-sample_pages_3_sec_4.png
# 般  |  00-sample_pages_3_sec_4.png
# 社  |  00-sample_pages_3_sec_4.png
# 會  |  00-sample_pages_3_sec_4.png
# 事  |  00-sample_pages_3_sec_4.png
# 業  |  00-sample_pages_3_sec_4.png
# に  |  00-sample_pages_3_sec_4.png
# 良  |  00-sample_pages_3_sec_4.png
# 味  |  00-sample_pages_3_sec_4.png
# す  |  00-sample_pages_3_sec_4.png
# る  |  00-sample_pages_3_sec_4.png
# を  |  00-sample_pages_3_sec_4.png
# 目  |  00-sample_pages_3_sec_4.png
# 的  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# す  |  00-sample_pages_3_sec_4.png
# る  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# 史  |  00-sample_pages_3_sec_4.png
# 村  |  00-sample_pages_3_sec_4.png
# 五  |  00-sample_pages_3_sec_4.png
# 百  |  00-sample_pages_3_sec_4.png
# 子  |  00-sample_pages_3_sec_4.png
# の  |  00-sample_pages_3_sec_4.png
# 御  |  00-sample_pages_3_sec_4.png
# 設  |  00-sample_pages_3_sec_4.png
# し  |  00-sample_pages_3_sec_4.png
# た  |  00-sample_pages_3_sec_4.png
# 密  |  00-sample_pages_3_sec_4.png
# 人  |  00-sample_pages_3_sec_4.png
# 固  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# 戰  |  00-sample_pages_3_sec_4.png
# 死  |  00-sample_pages_3_sec_4.png
# 者  |  00-sample_pages_3_sec_4.png
# の  |  00-sample_pages_3_sec_4.png
# 流  |  00-sample_pages_3_sec_4.png
# 族  |  00-sample_pages_3_sec_4.png
# 、  |  00-sample_pages_3_sec_4.png
# 及  |  00-sample_pages_3_sec_4.png
# new line
# ん  |  00-sample_pages_3_sec_4.png
# か  |  00-sample_pages_3_sec_4.png
# い  |  00-sample_pages_3_sec_4.png
# new line
# し  |  00-sample_pages_3_sec_4.png
# ん  |  00-sample_pages_3_sec_4.png
# 愛  |  00-sample_pages_3_sec_4.png
# 國  |  00-sample_pages_3_sec_4.png
# 心  |  00-sample_pages_3_sec_4.png
# 三  |  00-sample_pages_3_sec_4.png
# 名  |  00-sample_pages_3_sec_4.png
# 自  |  00-sample_pages_3_sec_4.png
# 分  |  00-sample_pages_3_sec_4.png
# の  |  00-sample_pages_3_sec_4.png
# 生  |  00-sample_pages_3_sec_4.png
# き  |  00-sample_pages_3_sec_4.png
# れ  |  00-sample_pages_3_sec_4.png
# 品  |  00-sample_pages_3_sec_4.png
# 主  |  00-sample_pages_3_sec_4.png
# を  |  00-sample_pages_3_sec_4.png
# 多  |  00-sample_pages_3_sec_4.png
# る  |  00-sample_pages_3_sec_4.png
# る  |  00-sample_pages_3_sec_4.png
# new line
# き  |  00-sample_pages_3_sec_4.png
# さ  |  00-sample_pages_3_sec_4.png
# け  |  00-sample_pages_3_sec_4.png
# ふ  |  00-sample_pages_3_sec_4.png
# こ  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# み  |  00-sample_pages_3_sec_4.png
# の  |  00-sample_pages_3_sec_4.png
# こ  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# は  |  00-sample_pages_3_sec_4.png
# を  |  00-sample_pages_3_sec_4.png
# か  |  00-sample_pages_3_sec_4.png
# け  |  00-sample_pages_3_sec_4.png
# る  |  00-sample_pages_3_sec_4.png
# こ  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# 又  |  00-sample_pages_3_sec_4.png
# 、  |  00-sample_pages_3_sec_4.png
# そ  |  00-sample_pages_3_sec_4.png
# の  |  00-sample_pages_3_sec_4.png
# こ  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# は  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# 上  |  00-sample_pages_3_sec_4.png
# 手  |  00-sample_pages_3_sec_4.png
# を  |  00-sample_pages_3_sec_4.png
# 出  |  00-sample_pages_3_sec_4.png
# す  |  00-sample_pages_3_sec_4.png
# こ  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# ○  |  00-sample_pages_3_sec_4.png
# 動  |  00-sample_pages_3_sec_4.png
# れ  |  00-sample_pages_3_sec_4.png
# あ  |  00-sample_pages_3_sec_4.png
# ひ  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# 合  |  00-sample_pages_3_sec_4.png
# 意  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# て  |  00-sample_pages_3_sec_4.png
# 、  |  00-sample_pages_3_sec_4.png
# new line
# 受  |  00-sample_pages_3_sec_4.png
# 正  |  00-sample_pages_3_sec_4.png
# は  |  00-sample_pages_3_sec_4.png
# は  |  00-sample_pages_3_sec_4.png
# 滿  |  00-sample_pages_3_sec_4.png
# 固  |  00-sample_pages_3_sec_4.png
# 造  |  00-sample_pages_3_sec_4.png
# 能  |  00-sample_pages_3_sec_4.png
# 在  |  00-sample_pages_3_sec_4.png
# 在  |  00-sample_pages_3_sec_4.png
# の  |  00-sample_pages_3_sec_4.png
# 部  |  00-sample_pages_3_sec_4.png
# 命  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# 成  |  00-sample_pages_3_sec_4.png
# 思  |  00-sample_pages_3_sec_4.png
# 八  |  00-sample_pages_3_sec_4.png
# （  |  00-sample_pages_3_sec_4.png
# （  |  00-sample_pages_3_sec_4.png
# 八  |  00-sample_pages_3_sec_4.png
# 八  |  00-sample_pages_3_sec_4.png
# 五  |  00-sample_pages_3_sec_4.png
# ）  |  00-sample_pages_3_sec_4.png
# new line
# る  |  00-sample_pages_3_sec_4.png
# こ  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# ひ  |  00-sample_pages_3_sec_4.png
# い  |  00-sample_pages_3_sec_4.png
# き  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# い  |  00-sample_pages_3_sec_4.png
# り  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# こ  |  00-sample_pages_3_sec_4.png
# の  |  00-sample_pages_3_sec_4.png
# 地  |  00-sample_pages_3_sec_4.png
# で  |  00-sample_pages_3_sec_4.png
# 結  |  00-sample_pages_3_sec_4.png
# は  |  00-sample_pages_3_sec_4.png
# れ  |  00-sample_pages_3_sec_4.png
# た  |  00-sample_pages_3_sec_4.png
# 條  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# ゐ  |  00-sample_pages_3_sec_4.png
# ず  |  00-sample_pages_3_sec_4.png
# み  |  00-sample_pages_3_sec_4.png
# （  |  00-sample_pages_3_sec_4.png
# 強  |  00-sample_pages_3_sec_4.png
# 氣  |  00-sample_pages_3_sec_4.png
# 風  |  00-sample_pages_3_sec_4.png
# 」  |  00-sample_pages_3_sec_4.png
# 名  |  00-sample_pages_3_sec_4.png
# （  |  00-sample_pages_3_sec_4.png
# あ  |  00-sample_pages_3_sec_4.png
# い  |  00-sample_pages_3_sec_4.png
# ね  |  00-sample_pages_3_sec_4.png
# ず  |  00-sample_pages_3_sec_4.png
# ず  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# る  |  00-sample_pages_3_sec_4.png
# ア  |  00-sample_pages_3_sec_4.png
# イ  |  00-sample_pages_3_sec_4.png
# コ  |  00-sample_pages_3_sec_4.png
# ン  |  00-sample_pages_3_sec_4.png
# （  |  00-sample_pages_3_sec_4.png
# （  |  00-sample_pages_3_sec_4.png
# 又  |  00-sample_pages_3_sec_4.png
# 又  |  00-sample_pages_3_sec_4.png
# は  |  00-sample_pages_3_sec_4.png
# 個  |  00-sample_pages_3_sec_4.png
# 徳  |  00-sample_pages_3_sec_4.png
# を  |  00-sample_pages_3_sec_4.png
# 現  |  00-sample_pages_3_sec_4.png
# す  |  00-sample_pages_3_sec_4.png
# こ  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# 皆  |  00-sample_pages_3_sec_4.png
# 學  |  00-sample_pages_3_sec_4.png
# new line
# 智  |  00-sample_pages_3_sec_4.png
# 造  |  00-sample_pages_3_sec_4.png
# 愛  |  00-sample_pages_3_sec_4.png
# 國  |  00-sample_pages_3_sec_4.png
# 婦  |  00-sample_pages_3_sec_4.png
# 入  |  00-sample_pages_3_sec_4.png
# 會  |  00-sample_pages_3_sec_4.png
# （  |  00-sample_pages_3_sec_4.png
# 名  |  00-sample_pages_3_sec_4.png
# 明  |  00-sample_pages_3_sec_4.png
# 至  |  00-sample_pages_3_sec_4.png
# 十  |  00-sample_pages_3_sec_4.png
# 十  |  00-sample_pages_3_sec_4.png
# 四  |  00-sample_pages_3_sec_4.png
# 年  |  00-sample_pages_3_sec_4.png
# 、  |  00-sample_pages_3_sec_4.png
# new line
# （  |  00-sample_pages_3_sec_4.png
# 疑  |  00-sample_pages_3_sec_4.png
# 氣  |  00-sample_pages_3_sec_4.png
# （  |  00-sample_pages_3_sec_4.png
# 名  |  00-sample_pages_3_sec_4.png
# の  |  00-sample_pages_3_sec_4.png
# 有  |  00-sample_pages_3_sec_4.png
# 色  |  00-sample_pages_3_sec_4.png
# を  |  00-sample_pages_3_sec_4.png
# 爭  |  00-sample_pages_3_sec_4.png
# び  |  00-sample_pages_3_sec_4.png
# て  |  00-sample_pages_3_sec_4.png
# あ  |  00-sample_pages_3_sec_4.png
# る  |  00-sample_pages_3_sec_4.png
# こ  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# 正  |  00-sample_pages_3_sec_4.png
# 唯  |  00-sample_pages_3_sec_4.png
# な  |  00-sample_pages_3_sec_4.png
# 認  |  00-sample_pages_3_sec_4.png
# 議  |  00-sample_pages_3_sec_4.png
# を  |  00-sample_pages_3_sec_4.png
# 得  |  00-sample_pages_3_sec_4.png
# よ  |  00-sample_pages_3_sec_4.png
# う  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# す  |  00-sample_pages_3_sec_4.png
# る  |  00-sample_pages_3_sec_4.png
# ゝ  |  00-sample_pages_3_sec_4.png
# こ  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# き  |  00-sample_pages_3_sec_4.png
# 達  |  00-sample_pages_3_sec_4.png
# new line
# し  |  00-sample_pages_3_sec_4.png
# ち  |  00-sample_pages_3_sec_4.png
# ま  |  00-sample_pages_3_sec_4.png
# き  |  00-sample_pages_3_sec_4.png
# ん  |  00-sample_pages_3_sec_4.png
# （  |  00-sample_pages_3_sec_4.png
# 愛  |  00-sample_pages_3_sec_4.png
# 國  |  00-sample_pages_3_sec_4.png
# 時  |  00-sample_pages_3_sec_4.png
# 金  |  00-sample_pages_3_sec_4.png
# 名  |  00-sample_pages_3_sec_4.png
# 名  |  00-sample_pages_3_sec_4.png
# 外  |  00-sample_pages_3_sec_4.png
# new line
# 一  |  00-sample_pages_3_sec_4.png
# 人  |  00-sample_pages_3_sec_4.png
# 一  |  00-sample_pages_3_sec_4.png
# new line
# （  |  00-sample_pages_3_sec_4.png
# 錢  |  00-sample_pages_3_sec_4.png
# 理  |  00-sample_pages_3_sec_4.png
# 條  |  00-sample_pages_3_sec_4.png
# 約  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# 名  |  00-sample_pages_3_sec_4.png
# new line
# 日  |  00-sample_pages_3_sec_4.png
# 一  |  00-sample_pages_3_sec_4.png
# new line
# 錢  |  00-sample_pages_3_sec_4.png
# つ  |  00-sample_pages_3_sec_4.png
# つ  |  00-sample_pages_3_sec_4.png
# 頃  |  00-sample_pages_3_sec_4.png
# け  |  00-sample_pages_3_sec_4.png
# 入  |  00-sample_pages_3_sec_4.png
# new line
# て  |  00-sample_pages_3_sec_4.png
# こ  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# ふ  |  00-sample_pages_3_sec_4.png
# じ  |  00-sample_pages_3_sec_4.png
# new line
# 「  |  00-sample_pages_3_sec_4.png
# と  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
# new line
# 「  |  00-sample_pages_3_sec_4.png
# 町  |  00-sample_pages_3_sec_4.png
# 。  |  00-sample_pages_3_sec_4.png
